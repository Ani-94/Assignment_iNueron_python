# %%
1.What are the two values of the Boolean data type? How do you write them?
 Answer: True and false
 
2. What are the three different types of Boolean operators?
Answer: And or and not

3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).

Answer:
A    B      A AND B      A or B   
0    0         0	       0
0    1         0           1
1    0         0           1
1    1         1           1

A   A Not
0    1
1    0

4. What are the values of the following expressions?

(5 > 4) and (3 == 5) false
not (5 > 4)  true
(5 > 4) or (3 == 5)  true
not ((5 > 4) or (3 == 5))   false
(True and True) and (True == False) False
(not False) or (not True) True

5. What are the six comparison operators?

Answer:
Greater than >
Greater than or equal to >=
Lesser than <
Lesser than or equal to <=
equal to ==
Not equal to !=

6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.

Answer:
The symbol ‘=’ is used once for assigning while twice for comparision ‘==’
example
a= b+c is assignment where the sum b and c is stored or assigned in a, also a depicts the memory location where the sum is stored
a == (b+c) is comparision, where the data stored in a is compared against the sum of data stored in both b and c 


7. Identify the three blocks in this code:
spam = 0
if spam == 10:     1
print('eggs')      
if spam > 5:       2
print('bacon')   
else:              3
print('ham')       
print('spam')
print('spam')


8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.

Answer:
spam = 0
if spam == 1:
	print('Hello')
else if spam ==2:
print('Howdy')
else:
print('Greetings')   

9.If your programme is stuck in an endless loop, what keys you’ll press?
Answer: Ctrl+C

10. How can you tell the difference between break and continue?

Answer:
Break –terminates the execution of remaining loop or iteration
Continue – terminates the execution of present loop or iteration and then executes the very next iteration or loop


11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?

Answer:
range(10)  - returns numbers from 0 by default 9 in steps of 1 by default, that returns values from zero to number previous to mentioned value
range(0,10)  - returns numbers from 0 as specified to 9 in steps of 1 by default, or the very 1st number in series will be mentioned and the function terminated to number previous to mentioned value
range(0,10,1)  - returns numbers from 0 as specified to 9 in steps of 1 as mentioned, or increments by any other value mentioned


12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.

Answer
for i in range(1,11,1):
	print(i)
i=1
while i<=10:
	print(i)
	i+=1


13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?

Answer:
Assign spam to a variable
a = spam()
and then bacon can be called as follows:
a.bacon()
