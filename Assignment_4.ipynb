# %%
1. What exactly is []?
Answer:
[] signifies an empty list to which elements can be added

2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)
Answer:
By using the function insert() hello can be replaced with the 3rd element in the list.


Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.

3. What is the value of spam[int(int('3' * 2) / 11)]?
Answer:
'd'

4. What is the value of spam[-1]?
Answer:
‘d’

5. What is the value of spam[:2]?
Answer:
‘a’ ‘b’ ‘c’


Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.

6. What is the value of bacon.index('cat')?
Answer:
1

7. How does bacon.append(99) change the look of the list value in bacon?
 [3.14, 'cat,' 11, 'cat,' True, 99]

8. How does bacon.remove('cat') change the look of the list in bacon?
 [3.14, 'cat,' 11, True, 99]

9. What are the list concatenation and list replication operators?
Answer:
list concatenation adds the new list at the end of an another list
list replication duplicates the list by n number times in to an another new list

10. What is difference between the list methods append() and insert()?
Answer:
Append(): updates the list by adding the query/s as a single element at the end of the list
insert(): replaces an element of the list with desired element. Or the input element a a specified index will replace the element at that index

11. What are the two methods for removing items from a list?
Answer:
remove() : to remove specified element in the list
pop(): to remove element at a specified index

12. Describe how list values and string values are identical.
Answer:
Both list and string are sequences that is a character in a string or an element in a list can be called by mentioning their index number

13. What's the difference between tuples and lists?
Answer:
List are mutable, have a lot of methods to manipulate it and lists are more suitable in modification related operation like inserting elements or removing themselves
While tuples are immutable, dont have a lot of methods but best suitable for accessing elements from it.

14. How do you type a tuple value that only contains the integer 42?
Answer:
t= (42,)

15. How do you get a list value's tuple form? How do you get a tuple value's list form?
Answer:
For list value’s tuple form we use zip and iter functions as shown:
[x for x in zip(*iter[(list)])]
For tuple value’s list form we use zip func as shown:
list(zip(list1,list2,list3,’’’)

16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?
Answer:
They contain references or memory location of the elements

17. How do you distinguish between copy.copy() and copy.deepcopy()?
Answer:
copy.copy(): just copies the reference of the original object thus the original data will be
             affected if the copied data is manipulated since only the reference is copied but the object remains the same, so changing the properties of copied object will effect the properties of original object
copy.deepcopy(): copies the content to new reference thus the original data will not be 
             affected if the copied data is manipulated
